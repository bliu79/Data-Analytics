# %% [markdown]
# # Step 1 Enviorment Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
# %matplotlib inline
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # step2 Data Collection

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')
df
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...            ...         ...         ...      ...    ...     ...
# 936738  2021-01-16  Sweetwater     Wyoming  56037.0   3280    26.0
# 936739  2021-01-16       Teton     Wyoming  56039.0   2614     4.0
# 936740  2021-01-16       Uinta     Wyoming  56041.0   1813     9.0
# 936741  2021-01-16    Washakie     Wyoming  56043.0    841    23.0
# 936742  2021-01-16      Weston     Wyoming  56045.0    602     4.0
#
# [936743 rows x 6 columns]

# %%
df.head(20)
# Out:
#           date       county       state     fips  cases  deaths
# 0   2020-01-21    Snohomish  Washington  53061.0      1     0.0
# 1   2020-01-22    Snohomish  Washington  53061.0      1     0.0
# 2   2020-01-23    Snohomish  Washington  53061.0      1     0.0
# 3   2020-01-24         Cook    Illinois  17031.0      1     0.0
# 4   2020-01-24    Snohomish  Washington  53061.0      1     0.0
# 5   2020-01-25       Orange  California   6059.0      1     0.0
# 6   2020-01-25         Cook    Illinois  17031.0      1     0.0
# 7   2020-01-25    Snohomish  Washington  53061.0      1     0.0
# 8   2020-01-26     Maricopa     Arizona   4013.0      1     0.0
# 9   2020-01-26  Los Angeles  California   6037.0      1     0.0
# 10  2020-01-26       Orange  California   6059.0      1     0.0
# 11  2020-01-26         Cook    Illinois  17031.0      1     0.0
# 12  2020-01-26    Snohomish  Washington  53061.0      1     0.0
# 13  2020-01-27     Maricopa     Arizona   4013.0      1     0.0
# ...

# %%
df.tail(20)
# Out:
#               date       county    state     fips  cases  deaths
# 936723  2021-01-16       Carbon  Wyoming  56007.0   1088    16.0
# 936724  2021-01-16     Converse  Wyoming  56009.0    885    13.0
# 936725  2021-01-16        Crook  Wyoming  56011.0    399     9.0
# 936726  2021-01-16      Fremont  Wyoming  56013.0   4239    71.0
# 936727  2021-01-16       Goshen  Wyoming  56015.0   1076    19.0
# 936728  2021-01-16  Hot Springs  Wyoming  56017.0    315     2.0
# 936729  2021-01-16      Johnson  Wyoming  56019.0    582     9.0
# 936730  2021-01-16      Laramie  Wyoming  56021.0   7728    75.0
# 936731  2021-01-16      Lincoln  Wyoming  56023.0   1052    11.0
# 936732  2021-01-16      Natrona  Wyoming  56025.0   7071   103.0
# 936733  2021-01-16     Niobrara  Wyoming  56027.0    145     2.0
# 936734  2021-01-16         Park  Wyoming  56029.0   2400    16.0
# 936735  2021-01-16       Platte  Wyoming  56031.0    516     9.0
# ...

# %% [markdown]
# # Task 3: Data wrangling and EDA (exploratory data analysis)

# %%
#rename fips to COVID
df= df.rename(columns = {'fips':'COVID'})
df
# Out:
#               date      county       state    COVID  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...            ...         ...         ...      ...    ...     ...
# 936738  2021-01-16  Sweetwater     Wyoming  56037.0   3280    26.0
# 936739  2021-01-16       Teton     Wyoming  56039.0   2614     4.0
# 936740  2021-01-16       Uinta     Wyoming  56041.0   1813     9.0
# 936741  2021-01-16    Washakie     Wyoming  56043.0    841    23.0
# 936742  2021-01-16      Weston     Wyoming  56045.0    602     4.0
#
# [936743 rows x 6 columns]

# %%
drop_cols = ['COVID']
df.drop(drop_cols, inplace=True, axis=1)
df
# Out:
#               date      county       state  cases  deaths
# 0       2020-01-21   Snohomish  Washington      1     0.0
# 1       2020-01-22   Snohomish  Washington      1     0.0
# 2       2020-01-23   Snohomish  Washington      1     0.0
# 3       2020-01-24        Cook    Illinois      1     0.0
# 4       2020-01-24   Snohomish  Washington      1     0.0
# ...            ...         ...         ...    ...     ...
# 936738  2021-01-16  Sweetwater     Wyoming   3280    26.0
# 936739  2021-01-16       Teton     Wyoming   2614     4.0
# 936740  2021-01-16       Uinta     Wyoming   1813     9.0
# 936741  2021-01-16    Washakie     Wyoming    841    23.0
# 936742  2021-01-16      Weston     Wyoming    602     4.0
#
# [936743 rows x 5 columns]

# %%
df.describe()
# Out:
#               cases         deaths
# count  9.367430e+05  916734.000000
# mean   2.220427e+03      57.090916
# std    1.163864e+04     461.272771
# min    0.000000e+00       0.000000
# 25%    4.100000e+01       0.000000
# 50%    2.650000e+02       5.000000
# 75%    1.142000e+03      24.000000
# max    1.004322e+06   25970.000000

# %%
df.columns
# Out:
# Index(['date', 'county', 'state', 'cases', 'deaths'], dtype='object')

# %%
df.groupby(['date','state'])['cases'].sum()
# Out:
# date        state
# 2020-01-21  Washington            1
# 2020-01-22  Washington            1
# 2020-01-23  Washington            1
# 2020-01-24  Illinois              1
#             Washington            1
#                               ...
# 2021-01-16  Virginia         429391
#             Washington       290896
#             West Virginia    108124
#             Wisconsin        566275
#             Wyoming           49068
# Name: cases, Length: 17614, dtype: int64

# %%
df.groupby(['date','state'])['cases'].sum().plot(x='date',y='deaths')
# Out:
# <AxesSubplot:xlabel='date,state'>

# %%
sns.lineplot(x='date',y='cases',data=df)
# Out:
# <AxesSubplot:xlabel='date', ylabel='cases'>

# %%
sns.lineplot(x='date',y='deaths',data=df)
# Out:
# <AxesSubplot:xlabel='date', ylabel='deaths'>

# %% [markdown]
# # Task 4: Understand NY COVID 19 data in last 30 days

# %%
dfny= df[df['state']=='New York']
dfny
# Out:
#               date         county     state  cases  deaths
# 416     2020-03-01  New York City  New York      1     0.0
# 448     2020-03-02  New York City  New York      1     0.0
# 482     2020-03-03  New York City  New York      2     0.0
# 518     2020-03-04  New York City  New York      2     0.0
# 519     2020-03-04    Westchester  New York      9     0.0
# ...            ...            ...       ...    ...     ...
# 935396  2021-01-16     Washington  New York   1424    21.0
# 935397  2021-01-16          Wayne  New York   3568    50.0
# 935398  2021-01-16    Westchester  New York  82932  1780.0
# 935399  2021-01-16        Wyoming  New York   2075    41.0
# 935400  2021-01-16          Yates  New York    783    16.0
#
# [17736 rows x 5 columns]

# %%
dfny1 = dfny.groupby(['date','state',]) ['cases','deaths'].sum()
dfny1.tail(30)
# Out:
# <ipython-input-45-6b5f4344d9ab>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dfny1 = dfny.groupby(['date','state',]) ['cases','deaths'].sum()
#                        cases   deaths
# date       state
# 2020-12-18 New York   832033  35775.0
# 2020-12-19 New York   841946  35897.0
# 2020-12-20 New York   851400  36017.0
# 2020-12-21 New York   860856  36147.0
# 2020-12-22 New York   871155  36300.0
# 2020-12-23 New York   882895  36454.0
# 2020-12-24 New York   896242  36604.0
# 2020-12-25 New York   909123  36739.0
# 2020-12-26 New York   920171  36870.0
# 2020-12-27 New York   928376  37000.0
# 2020-12-28 New York   938710  37118.0
# 2020-12-29 New York   950730  37256.0
# 2020-12-30 New York   963647  37412.0
# 2020-12-31 New York   979040  37557.0
# 2021-01-01 New York   996073  37733.0
# 2021-01-02 New York  1011922  37854.0
# 2021-01-03 New York  1024154  38001.0
# ...

# %%
dfny1.tail(30).describe()
# Out:
#               cases        deaths
# count  3.000000e+01     30.000000
# mean   1.012553e+06  37893.600000
# std    1.223925e+05   1384.982624
# min    8.320330e+05  35775.000000
# 25%    9.118850e+05  36771.750000
# 50%    1.003998e+06  37793.500000
# 75%    1.115081e+06  38992.250000
# max    1.229124e+06  40376.000000

# %%
# plot the case growth curve for NY last 30 days
sns.lineplot (x= 'date', y='cases', data = dfny1.tail(30))
# Out:
# <AxesSubplot:xlabel='date', ylabel='cases'>

# %%
# date for NY death rate last 30 days
dfny1_deathrate = dfny1['deaths']/dfny1['cases']
dfny1['death_rate'] = dfny1_deathrate
dfny1.tail(30)
# Out:
#                        cases   deaths  death_rate
# date       state
# 2020-12-18 New York   832033  35775.0    0.042997
# 2020-12-19 New York   841946  35897.0    0.042636
# 2020-12-20 New York   851400  36017.0    0.042303
# 2020-12-21 New York   860856  36147.0    0.041990
# 2020-12-22 New York   871155  36300.0    0.041669
# 2020-12-23 New York   882895  36454.0    0.041289
# 2020-12-24 New York   896242  36604.0    0.040842
# 2020-12-25 New York   909123  36739.0    0.040411
# 2020-12-26 New York   920171  36870.0    0.040069
# 2020-12-27 New York   928376  37000.0    0.039855
# 2020-12-28 New York   938710  37118.0    0.039541
# 2020-12-29 New York   950730  37256.0    0.039187
# 2020-12-30 New York   963647  37412.0    0.038823
# 2020-12-31 New York   979040  37557.0    0.038361
# 2021-01-01 New York   996073  37733.0    0.037882
# 2021-01-02 New York  1011922  37854.0    0.037408
# 2021-01-03 New York  1024154  38001.0    0.037105
# ...

# %%
# plot death curve for NY last 30 days
sns.lineplot (x= 'date', y='deaths', data = dfny1.tail(30))
# Out:
# <AxesSubplot:xlabel='date', ylabel='deaths'>

# %%
# Plot death rate curve for NY last 30 days
sns.lineplot (x= 'date', y='death_rate', data = dfny1.tail(30))
# Out:
# <AxesSubplot:xlabel='date', ylabel='death_rate'>

# %% [markdown]
# Understanding of the data:
#
# From the data of NY for the last 30 days, both of cases and deaths are keeping growing rapidly because their growth curves are steeply upward in a similar way.
# However, the death rate keep dropping a lot.

# %% [markdown]
# # Task 5: Comparing COVID 19 data from different states

# %%
# data for five states
df3=df.query('state in ["New York","Florida","Texas","Illinois","California"]')
df3_deathrate = df3['deaths']/df3['cases']
df3['death_rate'] = df3_deathrate
df3
# Out:
# <ipython-input-51-67bfc71ef199>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['death_rate'] = df3_deathrate
#               date       county       state  cases  deaths  death_rate
# 3       2020-01-24         Cook    Illinois      1     0.0    0.000000
# 5       2020-01-25       Orange  California      1     0.0    0.000000
# 6       2020-01-25         Cook    Illinois      1     0.0    0.000000
# 9       2020-01-26  Los Angeles  California      1     0.0    0.000000
# 10      2020-01-26       Orange  California      1     0.0    0.000000
# ...            ...          ...         ...    ...     ...         ...
# 936368  2021-01-16         Wood       Texas   2517    85.0    0.033770
# ...

# %%
# total cases and deaths
df_5states_groupby= df3.groupby(['date','state'])['cases','deaths'].sum()
df_5states_groupby.tail(10)
# Out:
# <ipython-input-52-e0a02a4598b4>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_5states_groupby= df3.groupby(['date','state'])['cases','deaths'].sum()
#                          cases   deaths
# date       state
# 2021-01-15 California  2937376  32947.0
#            Florida     1548059  23798.0
#            Illinois    1062121  19876.0
#            New York    1213179  40203.0
#            Texas       2096526  32212.0
# 2021-01-16 California  2974966  33393.0
#            Florida     1560178  24003.0
#            Illinois    1067230  20021.0
#            New York    1229124  40376.0
#            Texas       2114858  32581.0

# %%
# adding death rate data for five states
df_5states_deathrate = df_5states_groupby['deaths']/df_5states_groupby['cases']
df_5states_groupby['death_rate'] = df_5states_deathrate
df_5states_groupby.tail(10)
# Out:
#                          cases   deaths  death_rate
# date       state
# 2021-01-15 California  2937376  32947.0    0.011216
#            Florida     1548059  23798.0    0.015373
#            Illinois    1062121  19876.0    0.018713
#            New York    1213179  40203.0    0.033139
#            Texas       2096526  32212.0    0.015364
# 2021-01-16 California  2974966  33393.0    0.011225
#            Florida     1560178  24003.0    0.015385
#            Illinois    1067230  20021.0    0.018760
#            New York    1229124  40376.0    0.032849
#            Texas       2114858  32581.0    0.015406

# %%
df_5states_groupby.describe()
# Out:
#               cases        deaths   death_rate
# count  1.701000e+03   1701.000000  1701.000000
# mean   4.777450e+05  12583.085244     0.029893
# std    5.006652e+05  11390.191159     0.022726
# min    1.000000e+00      0.000000     0.000000
# 25%    5.743900e+04   2018.000000     0.017084
# 50%    3.789240e+05   9491.000000     0.020531
# 75%    7.449800e+05  19461.000000     0.040988
# max    2.974966e+06  40376.000000     0.285714

# %%
# plot case growth curve for five states
sns.lineplot(x='date', y='cases', hue='state', data=df_5states_groupby)
# Out:
# <AxesSubplot:xlabel='date', ylabel='cases'>

# %%
# plot death growth curve for five states
sns.lineplot(x='date', y='deaths', hue='state', data=df_5states_groupby)
# Out:
# <AxesSubplot:xlabel='date', ylabel='deaths'>

# %%
# plot death rate growth curve for five states
sns.lineplot(x='date', y='death_rate', hue='state', data=df_5states_groupby)
# Out:
# <AxesSubplot:xlabel='date', ylabel='death_rate'>

# %% [markdown]
# # Task 6: Conclusion

# %% [markdown]
# 1, Cases
#
#     a)In the first 2 months, reportedly few cases in these five states.
#
#     b)Suddenly in March, the case in NY exponentially increased as its first sharp curve came out, then in June became a flat line in a plateau until November.
#
#     c)The cases development in 3 states, CA, TX, and FL, remained few as their growth curves could keep flat in a lower position until June 2020. And IL could even keep this trend by September 2020.
#
#     d)However, from October to now, all of the five states entered into a rapidly increasing phase. Especially in California, its curve is just like a vertical line shooting to the ceiling of the plot, and others share the same steeply upward curves.
#
#     e)Until now, CA has the most cases, which is almost three times in IL.
#
# 2, Deaths
#
#     a)The deaths curves are similar to the cases, except NY’s position is much higher than other states, which means, the death numbers in NY are much greater than others all the time from March 2020.
#
#     b)And, currently, all of these five states are experiencing the same trend of death, going up.
#
# 3, Death Rate
#
#     a)In total, even though CA and TX have the most cases, their death rates are the lowest.
#
#     b)NY has the second-least cases, but its total death and death rate are the highest, which is over twice in the TX, and almost three times in CA.
#
#     c)However, the trends of death rate in all of 5 states are continuously going down even though the numbers of cases and death keep increasing rapidly since Nov..
